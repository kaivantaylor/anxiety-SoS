# %%
import fitbit
import gather_keys_oauth2 as Oauth2
from secret import fb_CLIENT_ID,fb_CLIENT_SECRET
import pandas as pd
import datetime
import os

CLIENT_ID = fb_CLIENT_ID
CLIENT_SECRET = fb_CLIENT_SECRET

server = Oauth2.OAuth2Server(CLIENT_ID, CLIENT_SECRET)
server.browser_authorize()

ACCESS_TOKEN = str(server.fitbit.client.session.token['access_token'])
REFRESH_TOKEN = str(server.fitbit.client.session.token['refresh_token'])

auth2_client = fitbit.Fitbit(CLIENT_ID, CLIENT_SECRET, oauth2=True, access_token=ACCESS_TOKEN, refresh_token=REFRESH_TOKEN)

yesterday = str((datetime.datetime.now() - datetime.timedelta(days=1)).strftime("%Y%m%d"))
yesterday2 = str((datetime.datetime.now() - datetime.timedelta(days=1)).strftime("%Y-%m-%d"))
today = str(datetime.datetime.now().strftime("%Y%m%d"))

fit_statsSl = auth2_client.sleep()
# Out:
# [14/Sep/2019:20:26:43] ENGINE Listening for SIGTERM.
# [14/Sep/2019:20:26:43] ENGINE Bus STARTING
# [14/Sep/2019:20:26:43] ENGINE Set handler for console events.
# CherryPy Checker:
# The Application mounted at '' has an empty config.
#
# [14/Sep/2019:20:26:43] ENGINE Started monitor thread 'Autoreloader'.
# [14/Sep/2019:20:26:43] ENGINE Serving on http://127.0.0.1:8080
# [14/Sep/2019:20:26:43] ENGINE Bus STARTED
# 127.0.0.1 - - [14/Sep/2019:20:26:45] "GET /?code=02c682294ca13b8b2812efb237b30ccf99382d01&state=kGr5N5Vg3fod0GPsRPQo4QgNZ3eAhC HTTP/1.1" 200 122 "" "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36"
# [14/Sep/2019:20:26:46] ENGINE Bus STOPPING
# [14/Sep/2019:20:26:55] ENGINE HTTP Server cherrypy._cpwsgi_server.CPWSGIServer(('127.0.0.1', 8080)) shut down
# [14/Sep/2019:20:26:55] ENGINE Removed handler for console events.
# [14/Sep/2019:20:26:55] ENGINE Stopped thread 'Autoreloader'.
# ...

# %%
fit_statsSl
# Out:
# {'sleep': [{'awakeCount': 1,
#    'awakeDuration': 3,
#    'awakeningsCount': 9,
#    'dateOfSleep': '2019-09-14',
#    'duration': 13140000,
#    'efficiency': 83,
#    'endTime': '2019-09-14T07:36:30.000',
#    'isMainSleep': True,
#    'logId': 23867907439,
#    'minuteData': [{'dateTime': '03:57:00', 'value': '1'},
#     {'dateTime': '03:58:00', 'value': '1'},
#     {'dateTime': '03:59:00', 'value': '1'},
#     {'dateTime': '04:00:00', 'value': '1'},
#     {'dateTime': '04:01:00', 'value': '1'},
#     {'dateTime': '04:02:00', 'value': '1'},
#     {'dateTime': '04:03:00', 'value': '1'},
#     {'dateTime': '04:04:00', 'value': '1'},
#     {'dateTime': '04:05:00', 'value': '1'},
#     {'dateTime': '04:06:00', 'value': '1'},
#     {'dateTime': '04:07:00', 'value': '2'},
#     {'dateTime': '04:08:00', 'value': '2'},
#     {'dateTime': '04:09:00', 'value': '2'},
#     {'dateTime': '04:10:00', 'value': '1'},
#     {'dateTime': '04:11:00', 'value': '1'},
# ...

# %%
type(fit_statsSl)
# Out:
# dict

# %%
fit_statsSl['summary']['stages']
# Out:
# {'deep': 51, 'light': 110, 'rem': 24, 'wake': 34}

# %%
fit_statsSl['sleep'][0]['minuteData']
# Out:
# [{'dateTime': '03:57:00', 'value': '1'},
#  {'dateTime': '03:58:00', 'value': '1'},
#  {'dateTime': '03:59:00', 'value': '1'},
#  {'dateTime': '04:00:00', 'value': '1'},
#  {'dateTime': '04:01:00', 'value': '1'},
#  {'dateTime': '04:02:00', 'value': '1'},
#  {'dateTime': '04:03:00', 'value': '1'},
#  {'dateTime': '04:04:00', 'value': '1'},
#  {'dateTime': '04:05:00', 'value': '1'},
#  {'dateTime': '04:06:00', 'value': '1'},
#  {'dateTime': '04:07:00', 'value': '2'},
#  {'dateTime': '04:08:00', 'value': '2'},
#  {'dateTime': '04:09:00', 'value': '2'},
#  {'dateTime': '04:10:00', 'value': '1'},
#  {'dateTime': '04:11:00', 'value': '1'},
#  {'dateTime': '04:12:00', 'value': '1'},
#  {'dateTime': '04:13:00', 'value': '1'},
#  {'dateTime': '04:14:00', 'value': '1'},
#  {'dateTime': '04:15:00', 'value': '1'},
#  {'dateTime': '04:16:00', 'value': '1'},
#  {'dateTime': '04:17:00', 'value': '1'},
#  {'dateTime': '04:18:00', 'value': '1'},
#  {'dateTime': '04:19:00', 'value': '1'},
# ...

# %%
stime_list = []
sval_list = []
for i in fit_statsSl['sleep'][0]['minuteData']:
    stime_list.append(i['dateTime'])
    sval_list.append(i['value'])
sleepdf = pd.DataFrame({'State':sval_list,
                     'Time':stime_list})

# %%
sleepdf
# Out:
#     State      Time
# 0       1  03:57:00
# 1       1  03:58:00
# 2       1  03:59:00
# 3       1  04:00:00
# 4       1  04:01:00
# ..    ...       ...
# 214     2  07:31:00
# 215     2  07:32:00
# 216     2  07:33:00
# 217     1  07:34:00
# 218     3  07:35:00
#
# [219 rows x 2 columns]

# %%
# Source: https://towardsdatascience.com/collect-your-own-fitbit-data-with-python-ff145fa10873
# Getting familiar with fitbit API
# Kaivan Taylor

import fitbit
import gather_keys_oauth2 as Oauth2
import pandas as pd
import datetime
from secret import fb_CLIENT_ID,fb_CLIENT_SECRET

CLIENT_ID = fb_CLIENT_ID
CLIENT_SECRET = fb_CLIENT_SECRET

server = Oauth2.OAuth2Server(CLIENT_ID, CLIENT_SECRET)
server.browser_authorize()

ACCESS_TOKEN = str(server.fitbit.client.session.token['access_token'])
REFRESH_TOKEN = str(server.fitbit.client.session.token['refresh_token'])

auth2_client = fitbit.Fitbit(CLIENT_ID, CLIENT_SECRET, oauth2=True, access_token=ACCESS_TOKEN, refresh_token=REFRESH_TOKEN)

yesterday = str((datetime.datetime.now() - datetime.timedelta(days=1)).strftime("%Y%m%d"))
yesterday2 = str((datetime.datetime.now() - datetime.timedelta(days=1)).strftime("%Y-%m-%d"))
today = str(datetime.datetime.now().strftime("%Y%m%d"))

_001fb = auth2_client.body()
print(_001fb)
# Out:
# [14/Sep/2019:14:58:01] ENGINE Listening for SIGTERM.
# [14/Sep/2019:14:58:01] ENGINE Bus STARTING
# CherryPy Checker:
# The Application mounted at '' has an empty config.
#
# [14/Sep/2019:14:58:01] ENGINE Set handler for console events.
# [14/Sep/2019:14:58:01] ENGINE Started monitor thread 'Autoreloader'.
# [14/Sep/2019:14:58:01] ENGINE Serving on http://127.0.0.1:8080
# [14/Sep/2019:14:58:01] ENGINE Bus STARTED
# 127.0.0.1 - - [14/Sep/2019:14:58:03] "GET /?code=8f52cedf5b2139cf7e00e8737920596baa005665&state=1z0oAqVCE9nWJvRtW4ovLv8QdurY8f HTTP/1.1" 200 122 "" "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36"
# [14/Sep/2019:14:58:04] ENGINE Bus STOPPING
# [14/Sep/2019:14:58:13] ENGINE HTTP Server cherrypy._cpwsgi_server.CPWSGIServer(('127.0.0.1', 8080)) shut down
# [14/Sep/2019:14:58:13] ENGINE Removed handler for console events.
# [14/Sep/2019:14:58:13] ENGINE Stopped thread 'Autoreloader'.
# ...

# %%
# STARTING TO CONVERT DATAFRAMES TO CSV FROM THIS TOP ALL THE WAY DOWN

# %%
_001fb = auth2_client.activities()['summary']
print(_001fb)
# Out:
# {'activeScore': -1, 'activityCalories': 526, 'caloriesBMR': 1338, 'caloriesOut': 1856, 'distances': [{'activity': 'total', 'distance': 2}, {'activity': 'tracker', 'distance': 2}, {'activity': 'loggedActivities', 'distance': 0}, {'activity': 'veryActive', 'distance': 0.32}, {'activity': 'moderatelyActive', 'distance': 0.47}, {'activity': 'lightlyActive', 'distance': 1.18}, {'activity': 'sedentaryActive', 'distance': 0}], 'elevation': 160, 'fairlyActiveMinutes': 15, 'floors': 16, 'heartRateZones': [{'caloriesOut': 1349.4123, 'max': 100, 'min': 30, 'minutes': 951, 'name': 'Out of Range'}, {'caloriesOut': 245.6032, 'max': 140, 'min': 100, 'minutes': 57, 'name': 'Fat Burn'}, {'caloriesOut': 0, 'max': 170, 'min': 140, 'minutes': 0, 'name': 'Cardio'}, {'caloriesOut': 0, 'max': 220, 'min': 170, 'minutes': 0, 'name': 'Peak'}], 'lightlyActiveMinutes': 100, 'marginalCalories': 294, 'restingHeartRate': 78, 'sedentaryMinutes': 895, 'steps': 4783, 'veryActiveMinutes': 9}

# %%
ssummarydf = pd.DataFrame({'Date':_001fb['activeScore'],
                'MainSleep':_001fb['activityCalories']
                        } ,index=[0])

# %%
ssummarydf
# Out:
#    Date  MainSleep
# 0    -1        526

# %%
_001fb = auth2_client.foods_log()
print(_001fb)
# Out:
# {'foods': [{'isFavorite': False, 'logDate': '2019-09-14', 'logId': 19202997998, 'loggedFood': {'accessLevel': 'PUBLIC', 'amount': 1, 'brand': 'Panera Bread', 'calories': 340, 'foodId': 17952399, 'locale': 'en_US', 'mealTypeId': 1, 'name': 'Blueberry Bagel', 'unit': {'id': 12, 'name': 'bagel', 'plural': 'bagels'}, 'units': [12]}}, {'isFavorite': False, 'logDate': '2019-09-14', 'logId': 19204433550, 'loggedFood': {'accessLevel': 'PUBLIC', 'amount': 1, 'brand': '', 'calories': 135, 'foodId': 1055, 'locale': 'en_US', 'mealTypeId': 1, 'name': 'Granola Bar, Peanut, Hard', 'unit': {'id': 226, 'name': 'oz', 'plural': 'oz'}, 'units': [226, 180, 147, 389]}, 'nutritionalValues': {'calories': 135, 'carbs': 18.06, 'fat': 6.07, 'fiber': 1.22, 'protein': 3.12, 'sodium': 78.81}}, {'isFavorite': False, 'logDate': '2019-09-14', 'logId': 19203194646, 'loggedFood': {'accessLevel': 'PUBLIC', 'amount': 1, 'brand': '', 'calories': 152, 'foodId': 82358, 'locale': 'en_US', 'mealTypeId': 3, 'name': 'Mashed Po
# ...

# %%
_001fb = auth2_client.foods_log_water()
print(_001fb)
# Out:
# {'summary': {'water': 0}, 'water': []}

# %%
_001fb = auth2_client.sleep()
print(_001fb)
# Out:
# {'sleep': [{'awakeCount': 1, 'awakeDuration': 3, 'awakeningsCount': 9, 'dateOfSleep': '2019-09-14', 'duration': 13140000, 'efficiency': 83, 'endTime': '2019-09-14T07:36:30.000', 'isMainSleep': True, 'logId': 23867907439, 'minuteData': [{'dateTime': '03:57:00', 'value': '1'}, {'dateTime': '03:58:00', 'value': '1'}, {'dateTime': '03:59:00', 'value': '1'}, {'dateTime': '04:00:00', 'value': '1'}, {'dateTime': '04:01:00', 'value': '1'}, {'dateTime': '04:02:00', 'value': '1'}, {'dateTime': '04:03:00', 'value': '1'}, {'dateTime': '04:04:00', 'value': '1'}, {'dateTime': '04:05:00', 'value': '1'}, {'dateTime': '04:06:00', 'value': '1'}, {'dateTime': '04:07:00', 'value': '2'}, {'dateTime': '04:08:00', 'value': '2'}, {'dateTime': '04:09:00', 'value': '2'}, {'dateTime': '04:10:00', 'value': '1'}, {'dateTime': '04:11:00', 'value': '1'}, {'dateTime': '04:12:00', 'value': '1'}, {'dateTime': '04:13:00', 'value': '1'}, {'dateTime': '04:14:00', 'value': '1'}, {'dateTime': '04:15:00', 'value': '1'}, {'
# ...

# %%
_001fb = auth2_client.bp()
print(_001fb)
# Out:
# {'bp': []}

# %%
_001fb = auth2_client.recent_foods()
print(_001fb)
# Out:
# [{'accessLevel': 'PUBLIC', 'amount': 1, 'brand': '', 'calories': 341, 'dateLastEaten': '2019-09-14', 'foodId': 82315, 'locale': 'en_US', 'mealTypeId': 3, 'name': 'Macaroni & Cheese', 'unit': {'id': 304, 'name': 'serving', 'plural': 'servings'}, 'units': [304, 228, 117, 170, 91, 256, 279, 226, 180, 147, 389]}, {'accessLevel': 'PUBLIC', 'amount': 1, 'brand': '', 'calories': 152, 'dateLastEaten': '2019-09-14', 'foodId': 82358, 'locale': 'en_US', 'mealTypeId': 3, 'name': 'Mashed Potatoes', 'unit': {'id': 304, 'name': 'serving', 'plural': 'servings'}, 'units': [304, 91, 256, 279, 226, 180, 147, 389]}, {'accessLevel': 'PUBLIC', 'amount': 1, 'brand': '', 'calories': 135, 'dateLastEaten': '2019-09-14', 'foodId': 1055, 'locale': 'en_US', 'mealTypeId': 1, 'name': 'Granola Bar, Peanut, Hard', 'unit': {'id': 226, 'name': 'oz', 'plural': 'oz'}, 'units': [226, 180, 147, 389]}, {'accessLevel': 'PUBLIC', 'amount': 1, 'brand': 'Panera Bread', 'calories': 340, 'dateLastEaten': '2019-09-14', 'foodId': 
# ...

# %%
_001fb = auth2_client.frequent_foods()
print(_001fb)
# Out:
# [{'accessLevel': 'PUBLIC', 'amount': 1, 'brand': '', 'calories': 341, 'dateLastEaten': '2019-09-14', 'foodId': 82315, 'locale': 'en_US', 'mealTypeId': 3, 'name': 'Macaroni & Cheese', 'unit': {'id': 304, 'name': 'serving', 'plural': 'servings'}, 'units': [304, 228, 117, 170, 91, 256, 279, 226, 180, 147, 389]}, {'accessLevel': 'PUBLIC', 'amount': 1, 'brand': '', 'calories': 135, 'dateLastEaten': '2019-09-14', 'foodId': 1055, 'locale': 'en_US', 'mealTypeId': 1, 'name': 'Granola Bar, Peanut, Hard', 'unit': {'id': 226, 'name': 'oz', 'plural': 'oz'}, 'units': [226, 180, 147, 389]}, {'accessLevel': 'PUBLIC', 'amount': 1, 'brand': '', 'calories': 152, 'dateLastEaten': '2019-09-14', 'foodId': 82358, 'locale': 'en_US', 'mealTypeId': 3, 'name': 'Mashed Potatoes', 'unit': {'id': 304, 'name': 'serving', 'plural': 'servings'}, 'units': [304, 91, 256, 279, 226, 180, 147, 389]}, {'accessLevel': 'PUBLIC', 'amount': 1, 'brand': 'Panera Bread', 'calories': 340, 'dateLastEaten': '2019-09-14', 'foodId': 
# ...

# %%
_001fb = auth2_client.favorite_foods()
print(_001fb)
# Out:
# []

# %%
_001fb = auth2_client.recent_activities()
print(_001fb)
# Out:
# []

# %%
_001fb = auth2_client.frequent_activities()
print(_001fb)
# Out:
# []

# %%
_001fb = auth2_client.food_goal()
print(_001fb)
# Out:
# {}

# %%
_001fb = auth2_client.get_bodyweight()
print(_001fb)
# Out:
# {'weight': []}

# %%
_001fb = auth2_client.intraday_time_series('activities/heart')
print(_001fb)
# Out:
# {'activities-heart': [{'dateTime': '2019-09-14', 'value': {'customHeartRateZones': [], 'heartRateZones': [{'caloriesOut': 1052.7859, 'max': 100, 'min': 30, 'minutes': 751, 'name': 'Out of Range'}, {'caloriesOut': 160.3123, 'max': 140, 'min': 100, 'minutes': 37, 'name': 'Fat Burn'}, {'caloriesOut': 0, 'max': 170, 'min': 140, 'minutes': 0, 'name': 'Cardio'}, {'caloriesOut': 0, 'max': 220, 'min': 170, 'minutes': 0, 'name': 'Peak'}], 'restingHeartRate': 78}}], 'activities-heart-intraday': {'dataset': [{'time': '00:59:00', 'value': 71}, {'time': '01:00:00', 'value': 72}, {'time': '01:01:00', 'value': 72}, {'time': '01:13:00', 'value': 75}, {'time': '01:14:00', 'value': 70}, {'time': '01:15:00', 'value': 77}, {'time': '01:16:00', 'value': 87}, {'time': '01:17:00', 'value': 96}, {'time': '01:18:00', 'value': 90}, {'time': '01:19:00', 'value': 83}, {'time': '01:20:00', 'value': 80}, {'time': '01:21:00', 'value': 87}, {'time': '01:22:00', 'value': 88}, {'time': '01:23:00', 'value': 80}, {'tim
